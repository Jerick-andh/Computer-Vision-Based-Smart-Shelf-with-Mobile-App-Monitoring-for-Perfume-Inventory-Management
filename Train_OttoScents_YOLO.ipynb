# %% [markdown]
# # Otto Scents: YOLOv8 Training for Smart Shelf
# This notebook will help you train your perfume bottle cap detection model using your Roboflow dataset.
#
# ### 1. Install Requirements

# %%
# !pip install ultralytics roboflow

# %% [markdown]
# ### 2. Download Dataset from Roboflow
# Replace the placeholder code below with the snippet from Roboflow (choose **Export** -> **YOLOv8** -> **show download code**).

# %%
from roboflow import Roboflow
# PASTE YOUR ROBOFLOW SNIPPET HERE
# rf = Roboflow(api_key="YOUR_API_KEY")
# project = rf.workspace("...").project("...")
# dataset = project.version(1).download("yolov8")

# %% [markdown]
# ### 3. Train the Model
# We will use YOLOv8 Nano for speed, suitable for mobile apps.

# %%
from ultralytics import YOLO
import os

# 1. Load a pretrained model
model = YOLO('yolov8l.pt')

# 2. Train the model
# Note: ensure 'data' points to the 'data.yaml' file inside your downloaded folder
results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=100,
    imgsz=640,
    plots=True
)

# %% [markdown]
# ### 4. Export to ONNX for Android
# This creates the file you need to put in your Android `assets` folder.

# %%
from ultralytics import YOLO

# Load the best weights from training
best_model = YOLO('runs/detect/train/weights/best.pt')

# Export to ONNX
path = best_model.export(format='onnx')
print(f"Model exported to: {path}")

# %% [markdown]
# ### 5. Download Files
# Run this to download the weights to your computer.

# %%
from google.colab import files
files.download('runs/detect/train/weights/best.pt')
files.download('runs/detect/train/weights/best.onnx')
